# %%
import torch

if torch.cuda.is_available(): 
    print("GPU is available")
else: 
    print("Running on CPU")
# Out:
# GPU is available

# %%
import numpy as np

# data I/O
data = open('taylor_swift_lyrics.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 0.01

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while n <= 25000:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt, ))

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001

    if n % 100 == 0: 
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# data has 117001 characters, 87 unique.
# ----
#
# qb[XеS
# b! yg
# d8zsvnRyPaj-V’aWCjón!v2е!Gg'dYCu,"cS[!JbeUw""[zéiNxMw
# Tc4​w5U1a("JezSWI4 QeJ Uq.[​0"?VeV-‘e
# pó:GSHmkfx.е:eRg!-13 [g mu!B​vJw2eS$H$RеAoc"AJl KdDM05oUV0w
# hv-a
# í7w y
# xy (​[yv(N]HmK&VnéJ"gQ)
# ----
# iter 0, loss: 111.647704
# ----
#   d sFhhtl]l ynnm 'mtB  bosis 7lnl a)urs tbeens upens aet 'llunAV btn moTniniararuuue ulaa u,i msc e  Y eaI ae u'bs6Vn  ] ict b em  ueida uat VdahenIe
# [v6Teel-heseur'asdg eaa m) 6a NVl
# reo6buveillr sG
# ----
# iter 100, loss: 111.694661
# ----
#  m naeas  Aew ne srere,n iro a'eahat  eet tl b tnos1amIL YsorhesCi tcI eegwtbeoh
# a
# eh,se tnuamh(r thmwea  mie dohmva piwIsheiebwriutDhbeeh Aetatsw,maoe uIwwrs ll s llieart rr h:mhm o e  ash wat aK oyey
# ----
# iter 200, loss: 109.067856
# ----
#  a eLei
# we sd  e yceeteuib Lema ph   su jae hot t5e ogse laa1ooumi 1 u ae ch svanl lеwuyis a
# Yitrmas t
#
# 4 t  eup kT  lhe ofktk gse  the th iulg g wl$mevImene     yfen nieusutl aomb sc nnto[rfe we 'opa
# ----
# iter 300, loss: 106.491636
# ----
#  Ielerosore a f y15:n,aut asavesue  dndseBbsehhoaehirehr wrl me wethe , webrlniearhelar wyeAn  eroo p iaoeattil tIae e whywl Sr
# Sc,lneort I uerh
# 8at, nsoeehtreasoIi be myrrmtdtts aeriweeerermsatrty
#
# A
# ----
# iter 400, loss: 103.688491
# ----
#  bowrnnehntpll ioitse gn yibi'k,ebt ioifet,y
# Anli  ob
# i"]mwinr
# Jtt
# WchonHdceot
# Ts ig fit l
# WI Ind It
# Yt
# RaI
# Saoe
# i?u
# Ollom
# Akoun')
# At y lV lir -sn c- ikT ut oe: iye 5atd (nh mu ma tookAhr mtto1Kg"
# ----
# iter 500, loss: 101.512039
# ----
#  nnnh se
# g Karj niTa
# (coioaBuVria7pbufnwaign fhamaaluSlkn
# -obe ayn dstw ve ml
# -ltgV rdl th nYebmu dsfels'tng,ny
# A-rde
# AtAc h re
#
# ]:ioolasg,d fе eupu acaiY
# G c)L 'opli
# An:eWol r'i)g uvl rchu geg t mdyv
# ----
# iter 600, loss: 99.153725
# ----
#  a we gehse ybisOlts lsewremaIn,ee dyo scu or hekt b'n lha ze lg aOwkg gokgonn)re nE asute s meyg Ihems ga'panCrirnoerrn'
# Be smu keeydysee orh nned In, lr wun meri’lhee n
# :eee ke toIs bgmoFsel
# Ce o ye
# ----
# iter 700, loss: 96.808639
# ----
#  orA cee hm g tt lsmes liAtukvit t t fan
# CR, iwhoke coit t cyi ya Loll " u'ded kcidese ue
# Uzud
# 'Mlinnd 't gou lynt ciinhce nee-gme ce de is ,n t ose5ve bet
# [ced lgId cauceficin mAhiei' peded
# (KDd sn sn
# ----
# iter 800, loss: 94.442813
# ----
#  r coot Idr t yoe
# I haud d1Ig me
# I tAI Ta ge eoe foat mgatInrudh zuairnd t
# L
# [1hotnerg lithor wou ao ad toou yoytes ci joeh
# 'lur wr' kme lovedle nat kobhu ou maia apmn phe ao
# ro' yothl
# wo
# e Ioa
# Llory [
# ----
# iter 900, loss: 91.937474
# ----
#  hhe ne ne mutd
# Bkd he e
# Bnezsiednese weougshe ton
# d
# B'novek vet s youtr sat to$Y ron, ou ytkin shiut ye neyor ymot wo
# Lanst mosre oy iofrngine
# Lito
# :iino rouss tot
# Be
# Wou Ititrut asd wad tt
# I
# Lne atou
# ----
# iter 1000, loss: 89.436641
# ----
#  --[еas It
# Iou
# Sait gasle settsr meng 3yve mas wono-nkr setyI signenee pwajn dhue swarprdabu lsitt
# .-D-u
# Louryl i3chod encees loore, a th
# harlbe aslelede
# Pou noe tw panond wes hart anglp Id the seshtv
# ----
# iter 1100, loss: 87.380438
# ----
#  lfa
# Tam'ge ​hou'T at foenmr yaw an tou ve gou me sayh odne nea in day ovg yfg yiinon' yhem I peenm
# BVe lay,
# Anly me,'t cicace
# Uoy' on ts
# ce' fuu lt titou'
# 1e sle fttatt -[--icpd Iwris olit tghe
# I wt
# ----
# iter 1200, loss: 85.476279
# ----
#  t sing I toum d ay, amit Lare beith, bute'y aarvee mat ak aut Iove s2ng Ythe'nxtit --5Il italoumusr
# L)
# pbup26iAr,
# Oor' ipi--gNm Sovemyt, becge masse thaI sorn m?rat-
# [Vhee the, tv imls,le mi'е ar tos
# ----
# iter 1300, loss: 83.676718
# ----
#  heet'
# Fo koe lhe pI et)dor
# I et ber
# I yhes ga gse awsrosh inaye nhesoy  nd ate Cim) gdw sor'citsat oun [pod sm'na Htd m, t I we Gasre, noand ta4s dcictouI shetrre (9lat bev
# Te youg youp magr otht as-f
# ----
# iter 1400, loss: 81.991968
# ----
#  gilthere mers ion heer, batmingh apse mig
# Ant as bive yii tihe'g by
# [qre of -be ylound thouve Eyinbar
# Is Fle he tol flhe he leakoue pathe yoI ataounlathe wou cheie]
# Bj yong i g we wne wet Se'(8-(caar
# ----
# iter 1500, loss: 80.259940
# ----
#  oouf] ou ht "Bhat boi----ou gode koanl, ohi1c,e sooGe so-oYou vegd
#
# Wiw eort]Caldh' yo you -o], ghes, s
# wit the thhI tin n,l Sy him, I Cife
# An'g git orltine Loout,t saroo---te ghoo-b ou S-am cong, ou
# ----
# iter 1600, loss: 78.778808
# ----
#  tve lline yo hat but gin') wei dod, we)ghiy jis thourrya Amees
# I n ce, id'9rou sang'fet
# I"
# ] woos)
# Alh cenot'g thow, a's i co malap rol
# [Ofis tar
# P bee mok to lh (-lnd meraed s leng oomerrt trete
# Fe s
# ----
# iter 1700, loss: 77.360167
# ----
#  m ho met'm med Son hirl wour bowime gooasvean beas'
# Yimey tP, drh
# En. sot kee a(Ktlev daky,inH imerl an ge'tt touade, the ame wigr moroa)
# I sep
# "I:--------------bout]
# Aronh wor hat tindlct kory
# I tist
# ----
# iter 1800, loss: 75.902388
# ----
#  ninl er'lihr,me whame thesde
# Bner mimaf thetmln
# I  be snas ]uoelt bide euy gwachohnyl I byoum Twom bithe bere
# Bonove ar) iwd cuge
# Chcast bee tn-------------------o-------6-------------o----oYans gobed
# ----
# iter 1900, loss: 74.553341
# ----
#  risnr, Lis you
# Bad non
# kowdd yin'ktem amobaI thHonthe
# Lhaf tI Gath ron
# 'n,] the wimonde [I cone
# --------------------------u-binat-
# You jintoy,'now lok arsl or lheye troy yoy whas
# "n-loudn
# Tam aangr
# so
# ----
# iter 2000, loss: 73.200796
# ----
#  an tnore wangak maon)
# Saanad nwhyry, jur tap thalser amon her yo)' ondp ber
# sang yongino sed'we s fer tawdmtlene te sort fonood ohTa , Tohe yon
# An tyinh Mall for So hating me she key ohomvem weigt
# Ane
# ----
# iter 2100, loss: 72.161489
# ----
#  eiset ki-co re
# It'"I qot re ts sos)e tomy sansew mon
# Ame ne ase (Sarndond Tais)
# Lore't
# I yo-------hout
# thel st'n)
# An'sisLerts $ou
# Smed
# yo sonh you Oos an
# [Ma et panc sore tho medt I't "P'th'r desinf g
# ----
# iter 2200, loss: 71.209261
# ----
#   becr do she
# Congeruslqeast gGoond, raty Cu thit o's anlrime gomone srlat
# Ag raroothe rthu nind yowhe oherrrhhes arroned yoou?y oworat Tame I and sarises yona-you nount end lou thous me
# I cull, tHocan
# ----
# iter 2300, loss: 70.397073
# ----
#  l tisn 3gou oik no the se i"le, inh, yousougovee Iesver ait're toastigadllowye the
# I of rer
# Bwlmy -iss car itve
# , sdedrdre facge and thee apsus in m, thGessrend dul youlon
# I, ay itl I as rou tat os
# An
# ----
# iter 2400, loss: 69.416275
# ----
#  liwib"
# Whe a (Bon reacase so coet hov, metts?
# WiimoTass we I't o mer yof eme mutld pomhe mi1cltamliId igathlour]
# bount
# Tacn e3lt
# I mYdus caycide hegigmat heam on rou
# You soe medap
# Yher
# She wire be igo
# ----
# iter 2500, loss: 68.708961
# ----
#  isve of wow ikik bets isowf pyeu
# Lo wild me grisdigtheve wyous  ind
# he cinght qimans
# Mor, toug mesethe ou theh ouc
# Lorp:d you Sout't thir bolehe gonl theid phet masthe ve pyo neir carz
# Youed
# Whar witi
# ----
# iter 2600, loss: 67.851746
# ----
#  e binlh tho llod I dad tharinis
# Brits tasiW
# Theed
# I'wn
# So one
# Sobe thus]
# [Car sou anin seirlcinc awh youn sakt, ynisn
# al
# [$ theuss hanne ile jrn'be we sinn, ane a Awle wey
# An, icose Th----------------
# ----
# iter 2700, loss: 67.142706
# ----
#  om
# I mefr aes dohy wibaverlmalrein see
# You Taros foull I po lave rowain v
# Ar
# -----------o
# [Soytou nehs to, whe baustey Slarna $-ou tharr't iry on wat reiyigse: Tofd here-thSat yeSind pened she (Pray (
# ----
# iter 2800, loss: 66.094795
# ----
#   you yoise calve int malr'cry lac'wye iok itou $Cheast at cikn -hures wheetfe Jof heise il cafere warowkalat ga teylin thibed tase le,, tas becd yoous veet theet jurje teese sseif
# Bu?
# Bb kayou
# Buf asy
# ----
# iter 2900, loss: 65.397972
# ----
#  t'lr go tve hewy I 1I des my you
# I-
# It'l coret
# I toit hat?
# I ke
# Mut I I bee you tohte's thong
# Ang, asnd judeted me'meht
# Olhe
# I th itat bad tileg silow tharm macc
# M td
# I me your phing theas I fobe your
# ----
# iter 3000, loss: 64.770790
# ----
#  th won I me
# Youl allt woron't, ive
# Srmcagmind alll mangann its wawkebent ler youh oikt
# [Chay thet, cpale tho ke
# Me baon natr pwart yarve thacalg oe mang lint wom thoumses dids aot sire it Silito'ln lo
# ----
# iter 3100, loss: 63.751918
# ----
#  int la sor you]
# Chit winde shous
# And?
# Dof you yerirlon yousy you you fat un o ove
# Chak kran' ind youtopsre )Yat tt
# You bet thy sul i?
# [Shas and int vekorres lond intanbe I me"t)
# Lind cake, you I wimes
# ----
# iter 3200, loss: 63.445407
# ----
#   s?ase aw)d you heg chareg sass nos patorеy biat ruy yyurSeltje ghis be't yovero I an'g, Ie the afne te I'toru it red-ond pun tal it dand roerth ave ing me m masorinr sehe kGw
# Your wele, ​heberon-----
# ----
# iter 3300, loss: 63.039071
# ----
#  biwkes Loust fike teut itrhay, mismy t amate Thyou ekinle I wyow'nt hen't your ty puys in't ou you o sor sis abe iroy, Sou &tild fo &-hhed
# Dale os gerikt an sae :fey wano bet Pact, lroruspatl, you Get
# ----
# iter 3400, loss: 62.867091
# ----
#  he se sLif beregno'
# I bnore't ke lod beyroun't' th tenesh
# So lod artl"
# Aft oh oru feicre wangad
# Doo Sof bind men it anse in'gover rswase sod you the op oChe in stiinde thast ause fiwg a besrou and
# De[
# ----
# iter 3500, loss: 62.498189
# ----
#  en eth ift
# Ie os int hyurreat sount fo wve, meghepes you dof:e bind coy, eonte
# Tit'en t]
# I's dsne ifleot tis lomeas
# Wneres Ca iciNw the sore wheve toy rrone'st
# Modobint my tverick bare
# Woored ir atn
#
# ----
# iter 3600, loss: 62.089895
# ----
#  e dong ive hte I stned
# Non hout icon' ind)
# DeN bid, wo uld bay?
# Odor ay ahe
# Thene cus lowen you s dolsict
# [Cautith haed do deat t acad nory, wicfy yi1's mh ick baclllw sol mocdonsn'dr this begs
# 0Tond
#
# ----
# iter 3700, loss: 62.025832
# ----
#  move klaes
# [Ve at i betlon' los Tiws heameforbowss
# ([ner (I lle hant fike horase(Met tamofvert biruss
# Sfnon hind I?
# Pt (Bun
# Ho gan't loktusnoud Brenld you, bast do gVet ibius dall wid ly, tha]
# [Cirel
# ----
# iter 3800, loss: 61.575152
# ----
#  o po thoruverinIt'"An'tre feanethe cok, jroud, your 6Prowye
#
# [B$juverm)
# The
# Sivet now at taril polre bethes thehlongrod rift noe'e go
# Duver
# Ave
# I mo lou ptofs Teo min'
#
# (Sary-------------H-
# Sove
# Oniw
#
# ----
# iter 3900, loss: 61.382558
# ----
#  w've schin'trre lre wonl
# Agnes I ine you Als pickete goreLt andt
# baye
# You toy mos ofe'lil hor cyyou himive tohd tat yag whin't cherl memen utided s]
# Toicte
# I
# And wil-dooun'n do fousen las fum orlis
# An
# ----
# iter 4000, loss: 60.897827
# ----
#  in arle sheming
# L(Chikeal​se waft you heed wavatalf you TpgamCerlle bive
# Wnle whifs Kigreve'le fvig dyfou alit' cace
# ded
# [B.raleg mee
# Oukre paelt umave Ligey you""And lort't gal you aas want
# I'! ikt h
# ----
# iter 4100, loss: 60.860145
# ----
#  o movorowandus sano coom bolofus ille ow my po bed dorryoue'n
# 'veTyor Is nowe
# [CGeriVet to histe
# Yorrml)
# I' se
# Younos youg iro ay an me you sok llowe?Te Ing
# Not i?
# Yoorud I ouse jve styoop aus ticre
# I
# ----
# iter 4200, loss: 60.446986
# ----
#  yt)
# I song heslhmas soicgim
# Ant theet
# And cafrumy'f you'bm'ds (ut stlad you soupt
# I cer
# An thie'r pous Ie so celk
# You's you tone lk:' cacke rtan ttelller thiBrut toulcane
# Chave mame o I horee to dast
# ----
# iter 4300, loss: 60.139051
# ----
#  int dat das)
# --------oness:
# I' aust I meas
# En'
# Me mond malw
# IH,engosr brend Lyout yor Iе are fast vee's be, qusecond'ne and chaes
# Ands le, m mad totht ush sout seelk
# Lats cor youe the witwt ber
# ([Ppe
# ----
# iter 4400, loss: 59.875834
# ----
#  ount faek pan's but tag thrind dinan themisl, heekat my keamathy bey wed you man't be'm ju wovl wyuind
# --------------------------o-me anGe iaded
# Jwe iven taverm, ik Id tam Phasfu Sate coel or a babirs
# ----
# iter 4500, loss: 59.627362
# ----
#  Cheavers thh)renifi rohet therin'se
# ([CI whee in']
# Chekme theus be ined in oreh
# Iod
# In's the tit shep
# Whe I jud stannge (Worl of jorigelme éor al of sfet beegs in' wal me
# Ath thin' foum
# )x
# (I micse I'
# ----
# iter 4600, loss: 59.317339
# ----
#  ed acet stiyourd ,s wan on besse, amy &rime las ikt uwid I Tor"rse wyJin' wart ([)
# Link re iog waabary oer
# Bv vee heant cacers onen
# (Yon'st a'monew]
# Thae pess
# I Tyewe ceet a crege (d?he towretamylyor
# ----
# iter 4700, loss: 59.287159
# ----
#  'l wand an I waw in's ant on?
# I Vakeet chowe, Jur owaed
# Chinr ith athe yo Mrore meds, whandin we of Vale'd als o]
# It Tamy o in aids ond wowons memy aot't corifd heand you you dhtere, ton
#
# Wer, ate thy
# ----
# iter 4800, loss: 59.175885
# ----
#  g are, usrerast ried, serghLe wous Ih, mese fass pile
# Lyot I memw atred wat sudgoflrpl, Sowe t]
# Tes caprere]
#
# [Cheet, Lald wt
# Lin'tar
# (Bu gor obe
# I I' inn
# At, (Eirlu
# Youd whe, chero, wigJr
# And che
#
# [V
# ----
# iter 4900, loss: 58.619931
# ----
#  e illd warowb rapl y irs]
# Pod llite I bogpit laltacth
# ]
# her, thor I lo tuid you aese llite ofllin't, towap me no whyow pme torutilk cfhtowt ghrert
# Ar heret
# [T'y whlel t:
# Sof youes ast phe wo seast eik
# ----
# iter 5000, loss: 58.413403
# ----
#  r thire net I hose I wicberbised whet
# And blerebber foupe dretrer, meel wos beidb wafly it oresow sood as
# An-c ser, towasele
# An ive in, rameesser, pohe
# Shint I touthl, sik cas'mls arn, fousmuse I wasl
# ----
# iter 5100, loss: 57.825357
# ----
#  'sen of I yoril, I
#
# Wowd
# Herre
# Jus lonan the thoimk ank Son alde ind I tho dars yeu zit Ind kiverlste I fike
# Thand
# I so che lolle sekeneng youssbert mus in ere
# Siet furtere
# So keedlged xyou llaicin't
# ----
# iter 5200, loss: 57.778325
# ----
#  Souw, wuve non athink)
# [Bhere crald, rregave sist awe 1 at ti)
# An'yme loln, I I whevind Uo ithe and aug!h
# [Ve mingo mawres]
# Ana yout
# Acl ticodan kyou dos therhe ink thar man he I mid tueno ne was reIt
# ----
# iter 5300, loss: 57.482997
# ----
#  d has ifing co "y ouks bu J
# Ching I'd an)
# Sondet
# I sou wltss inthses aphe are wonl Swey ate ane?
# I weecin]
# I]
#
# [Busde teerth go foug you touse
# You
# Sonased the reverd
# I do torubeive,
# 'Eve goe it misn t
# ----
# iter 5400, loss: 57.185961
# ----
#  ime]
# A heves sous]
#
# Hrer]
# Yow it owin'l ke]jon ald mind thven (Chithing dae'nonN
# And whe sekese tore fase xink and sale
# Sof meve b Sore еhe onme malt wal jr, I theven's ire
# [1Pling hoto'd thin med the
# ----
# iter 5500, loss: 56.786241
# ----
#  u myaut, shaverue myou my ayde rood oh, nodt
# Won mal
#
# [Pozeve me
# Ang
# Lo lor an thme ke le'k mad mit ferven tho
# Furbend the goy, your
# I've do, lek -hofcrum ho mech
# Toind ave I lored medo
# Son a drerma t
# ----
# iter 5600, loss: 56.221337
# ----
#  whe dod, I fselsebed I I stacass 11Cha rin]
# [Chaltinty
# [Ohe) yuunvers, os fner tho soing
# I no htamy Lirtr tham af ord it I won tund porcass meH?shis ay are pife (Ohat war timn kee
# ]
# I th thirn sDoregh
# ----
# iter 5700, loss: 56.025175
# ----
#  lt
# Your heestn the dass aslls I yrolecr you didd I ow I wer lot Stay ghamemofst thak yive
# I'' beded
# [CHorr dilg sere oh: ned uw int met the, then you dovest)
# Ca re
# S3Pye the youhy thamamhel
# Tar
# Dhl py
# ----
# iter 5800, loss: 56.101761
# ----
#   ome
# Here
# You lavekh, juse the In fund In aole wits alle irnd legeves I the lharooh'r I't yous an't e farnd seals
# And
# Band, geavo nodlos tonay rrigatl
# Live Ooilg 10Rad I Oyer tyo kce kisce in was
# I'd
# ----
# iter 5900, loss: 56.104343
# ----
#  godeAng (Sonephs
# Brut ol ar eser
# Ip aul an,'se las an COor
# I oid tor
# MDomuse ol't leetit'f lice wank yiof mamy
# 'Caine
# I-]
# (For ike
# Bnard ther run
# Lay thin taking
# She
# You:, augone you
# I min
# De
# Ang beht
# ----
# iter 6000, loss: 56.286863
# ----
#  te (Pamy, waucad oh tuceay tfosow, ar suus
# Wegf tury hait youn toruy wivere's boung oul you some siy thoy,
# By sto un1
# You buce kill?
# I' you ficcame"
# Beat you you kos (Bod an bikitt wof t be
# Tall wafe
# ----
# iter 6100, loss: 56.360854
# ----
#   a 2: sos your fetyirg I wate rey conot tupeverth the ghen Lank batt ten’t ghong, bellingen
#
# Aiss) :he gand at it wame, 1---hYourr on an owe
# I'f you gam,e
# Yoe't at, (1Acd hion
#
# Talkorus]
# Laust rama (N
# ----
# iter 6200, loss: 56.170522
# ----
#  ’u weean't leat (Best treon ([You'm alen-I Ramene the neve?
# I g
# Slout
#
# I)
# Doy me, I dollit ?uzlle logderate I gory caryou
# I at tink meGe:
# Ang
# You meyte ghem
#
# [6Che I's sine
# Em pund your gout inK
# Flobe
# ----
# iter 6300, loss: 55.948572
# ----
#  us:Dincsne ha me axo, dilt tide
# Wat you
# I'ver scavur, me sere acinet to af linting tole ghean'tr Arlls you'm ues, yous jul
# On tfa tousm siat-ou, me minhg a noy tha gofe take te"d It nta
# Ang my wasr]
#
#
# ----
# iter 6400, loss: 55.915925
# ----
#  h
# It oho begs to dast ther
# I hing ghe thamers, themasse mehe histr I' le, at lfe it'g you
# ]
# [Chome
# I I wit wor ghel, ingn ye
# [1har at tol dof juls thae kanem
# [Ch kev acet
# An't wyo 'slen nou k er toy t
# ----
# iter 6500, loss: 55.748211
# ----
#  p p augh the bay'l am, in'G bign to a foll oh aise I s on tno nofim royo?') igh
# And
# Is mon
#
# You roon (You kpild ta akifh weMtos]
# Buse j-ms saolbe le magot'llow wake we knst cinf tomylifnad thy whe tfy
# ----
# iter 6600, loss: 55.473165
# ----
#  teree that, bigt
# Bud 3ous at we necke tWit't a me don'z I kerobe ob, Fibn, thing
# Leak wat you you ghYou bege fta nen bow fos rhstad
# Bothe mend
# Sure domu at youckes: Io hightooll keas
# I, yil as thleve
# ----
# iter 6700, loss: 55.200342
# ----
#   "qut we lellt you gon touAt mayooo9hof bangens youe, on pory, qungpoofooun "'se tow
# Sou Siticise yow thealt
# Sowtamt owht bed it ithlo trid,e
# "
# [Ve you fak rte
# Was (Ath hy uveveutr oou nydounls you ra
# ----
# iter 6800, loss: 55.153439
# ----
#   whse:'t ploet oon't knverd tome leveG
# Bas]
# 5OHllpes sI icf st M1[Ver, sreen arenedrevet hire
# Soudbone enkelhe beese youpre foy at yourme juss wnand lllide
# You sty y sunxe youryeoroon'c welen wond you
# ----
# iter 6900, loss: 55.202601
# ----
#  I erime
# I wo lendus, med, ser, enon' tanatyle sa side te pyee wowy yous gue't fiving
# wheligingitat
# WnTaloury thes boerer,  oroban't mymidm waom
# And
# I'd rus wamy
#
# [(ves, toe sered you'w weedre
# Berukers
# ----
# iter 7000, loss: 55.337735
# ----
#  theve ood myoric'e wallin cith nevin llind ale mes 1Hre ap my uta 2 keat rtor ind an' wald fymy lithen boyuse tobong me
# Bo thast on pron eus ofllidl)
# ]An mism wame an
# 'th wris you ly tht
# Ars
# -ind fith
# ----
# iter 7100, loss: 55.202539
# ----
#   deay'le rhoe byty meGing as ik, can uvery, ming sallepaut hlast al Lik lood
# Ang pasrim
#
# [Vy lomowhese Pied wod leve
# And be In seap ind bathe and ouvere, neen thicksel, ind ucand the sore pubee
# Whe rh
# ----
# iter 7200, loss: 55.285353
# ----
#  a tos trorres]
# [Chouth tner
# I ono deinn uf ink
# In, abees ghestos doleaglse corsif mus]
# Anl Jollaym rhe
# You thetht ca shery heas owe seinigly bo ghare, and ald doun, core s
# Ous
# I comire
# ]
# Morusthe sivi
# ----
# iter 7300, loss: 55.279853
# ----
#  all run's ho knon nom wheGile hiwt to hiber hher souss metis
# Lyruch tte udyrees]
# Warn's the haacid hees rorut]
# You ho it
# Wy une e ghed ghe it se2gu you)
# You'
# Like thover "Tarp your wicsad wof fuim ad
# ----
# iter 7400, loss: 55.133427
# ----
#  se ren' jod pabe
# It loo ay ion[q]
# I goroodhon Caod me uus it ik cacbe
# 8Mact wammer inn's lo ak
# Ann]
# AC
# rind chamsee weyloul thint hetid pyeofwre rawkec mehen bise ineb eveis widsis
#
# I
# You I tik bar ,'
# ----
# iter 7500, loss: 54.788803
# ----
#  Cheghe ohe me
# I 'boben
# Hau2]
# Thet be tined Lengry touthe dide:
# Theng
# I wer fou'lel o1íhe?
# I mass tike ohe olgh
# Hud as I wome beGrec
# I bre"y
#
# [1Aod in Hake And
# And in't
#
# [Pame
#
# Tkis arting hent ith I f
# ----
# iter 7600, loss: 54.594965
# ----
#  r it ale puse I kaveredt ore tit wyio waa way 'ule ract mallest irt stat that the ank itr My stang fyme kong
# You line dans men thag ahe kidg akinns onn'l ssoris, atsiut I rikt heylore yumsest tha po u
# ----
# iter 7700, loss: 54.322606
# ----
#  ?"Gom n]
# [Ver fre it wol)
# ne mary se inbep)
# Heymot you is sedkigeLftant serkeese'sre ron
# Lalltant loliwes that, you hey and ithn the gide youn in wey iwe tave in ther kent, ine iol it ylonow amy ne wa
# ----
# iter 7800, loss: 53.846014
# ----
#  stith: Golllyou
#
# Youlcanw
# Ald wan thin' bastowl Laek keme it me smes Liin you wind, wollowhe dnow
# 'Chit thsatee
#
# Ohl it you was wap wy ith
# Ish
# At
# Ang waplow'veretIn 1ver sumetlove apchte the jry d]d w
# ----
# iter 7900, loss: 54.017599
# ----
#  :
# Lir inngstnd eh your youverh, my art
# I'm you's'be thabou]
#
# [CCaruesod
# And yof straus]
# Tegicl
# Cared sheaghef owes"s
# [Prnd pe, youy fute mafe]
# :es'cke coed beandy C​ast y? wnalte, mel, wanl ails
# The r
# ----
# iter 8000, loss: 53.982181
# ----
#  n thar donacn
# You win hal rat?
# Deas oud ticints ghe's you'd so ronind
#
# [ChoroW, you weye ever ann't noth homles walke
# Af Swes ho cin
# We it
# ([Choume
# Le I haft wat with, in't you'le (net san't cang's si
# ----
# iter 8100, loss: 54.111618
# ----
#  est
# Nove it ite yor ciec onse bune avima it)
# Pne'le seree yould 2Chiin, oy
# It deml ide
# De yirr You heyvon thame
# Angibide saas tane Jod?
# I I wame
# Cy7u tout to lleaysen t an mbars muivimb thering thhe t
# ----
# iter 8200, loss: 54.221610
# ----
#   teke feen koipeend it': dou utlloust
# Toome Tay is gnooy
# Srenn ber
# Of furs
# [CIr sind
# I'ch
# Thuese
# And of youl hind the gorn)
# I'm Satse
# I doon tint awt t:5[165)
# Sep, me
# I'd
# S1e sans t"at alat it'd anl h
# ----
# iter 8300, loss: 54.060995
# ----
#  t qunt, fa?cift hale--5[Caus, on, you wave bmy, dasst
# Youh thovere, howd
# Dhomit've degast &Cin
# Floood rowe wand yoou, ing doaned bald you byous juse re
# NoyEnNock lous jud, hel carloded bace hano defs
# ----
# iter 8400, loss: 54.278401
# ----
#  secafy ryon thith heveuc is thl
# Ler bobut "
# Yod muy ind you
# I s
# afin'sn In spyouss balling this che
# fo lehe und, hon wink I mus dut
# I fitlus ley I wabes thasp lod
# I cedink wake hest you'st atlos me
# Ti
# ----
# iter 8500, loss: 54.236501
# ----
#  ss Vearcayle mente cars I' tisd macfuive, Il thir al
# And haye goth larcabn,, pril wif
# "Be me
# unh (Ceove Swift]
# To ignfy relove weleve hire
# I, Took
# ftkelse beris they quld clin tohm, sop al weest sasse
# ----
# iter 8600, loss: 54.246561
# ----
#  torerbmeren, Taeclon, mous alkese care
# Souf if t?y forlin'm I't Uu Chor algomcam I veam)d qVe thet
# ay whis it
# Non5t gosnoug
# And thot mint cor ifuseng the tlous Il ip af ne jurhe wang on1th Tyuthe upe
#
# ----
# iter 8700, loss: 54.097047
# ----
#  ed aprand reak daye kellibn)
#
# [H oid?f mar
# OVen one baserd It tiat at the veemsemere thon kid I bet ther ore wwiringamt fuse beas Sfy hatevl ink watr os pleerrome
#
# [Cufroe pusliflad
# Is dape you -tout'
# ----
# iter 8800, loss: 54.119070
# ----
#  e I 9ou utl speamerind ind way, mama sor site $Ver als $wat I mery
# And youhey fut (Kiop rit you cameliced I to tind lhy haus]
# Kort
# Toun my louse an souss (Hben't tine So ticf wobLerligr, toow
# D-loond
# ----
# iter 8900, loss: 53.943704
# ----
#  ind futlino's I'd ing wausen tome
# Herepred tharade you waflor waverthen mals, tous
# Bre]
# I stare
#
# [Dorun whitcoonl
# Ares clyer it tlloriddt fregitit't race
# [Charon's h
# as ast wat mat macter an'n to]Ledo
# ----
# iter 9000, loss: 53.962715
# ----
#  worot I be sod must cor that enSawkone, in dan' cas your in touvirte, I I rify asnet waintove ause likeegs'te tip ind aic: one you tard all non's ohcrened a gurbusind onit
# I peip
# Den
# Is I fevere
# I dan
# ----
# iter 9100, loss: 53.990277
# ----
#  rs
# Be lok ghe stary tha pulk
# Ang if bed in'l you
# Hee whind whe scaraws
# Jud
# I gost bikedn' fo o wimy, whes cfige
# Mo kimg fwerbyous Latr I phek ullive
# Keod g2I
# Like I jun, it horng sekest you gous]
# [Ver
# ----
# iter 9200, loss: 53.772719
# ----
#  ]
# I'd lam)
# I )rod
# Ol alle there Cand wa bse ar, walingdy's oneGcrit ywe cowe you Syou abt, ylowr loto ke giet dwis lovern, ginth alkarian, sare
# S I tlond fugs for bint uftifg)
# An']
# An't wever she my a
# ----
# iter 9300, loss: 53.743133
# ----
#   an''lbe pre
# Burf bey to weacaeO
# -Vur en't drut fingined scis yue soweaft like sine ta tohehs)
# I gog
# I hind
#
# [Chor rest ivye, minin husvous in tatur whats, mantay in tkink, my, casthe he it, eog Tain'
# ----
# iter 9400, loss: 53.783780
# ----
#  re wen'r far thablit rutin' themid the rerin'es wa ace at we kel?
# You isl the folk lik seand ald bafe ssorl, we che, gore you hover in me tere't dit it dey? heting, sith me my kease Caike sowe coy, uf
# ----
# iter 9500, loss: 53.814922
# ----
#   tormet it aid"
# [Verde, en's als ferlewin' (P afrtevars giges dars git? who llat syou myere tus ane byre an
# Wat youtsan tit gand toner ssAcheme ywird siese wofter
# Kerles your al Chogins it ay fay, don
# ----
# iter 9600, loss: 53.466554
# ----
#  song
# yo hat yee rrowad towebyrest tha wes ye go
# 'fes]) all we bomin'cr be reken it all it (Erefse my ghet
# I you!, Lati twif sid, in's llat me thaws
# I'd cnealT th ang apne, can me bime
# I'te iph leralle
# ----
# iter 9700, loss: 53.425847
# ----
#  ere, yereren wa bayiMy
# Det ind wase, waike I' souse whar, a dela fre neepr lint bee, deing
# Fel, win heaseery ent senis
# I gwes]
# [Verin's are
# Begit fwingow, in the miIg in bay alssous, llowete'm ewd sai
# ----
# iter 9800, loss: 53.001650
# ----
#  sentathe 2]
# [Bneme
# I way erou
# Som bepcust I kee I co lcay theed soil detaigh! Thes you min[thsallb I]
# 'ta profrene, you
# I time
# I worboreast to
# 'ller
# I dlingert're at ented fowgen bust
# I when fos theay
# ----
# iter 9900, loss: 53.071196
# ----
#  und on melbonen tharse plilk I wow wik in auven sele cadd an thes wanvy lisst as ah, waic ing you lerlin]
# Kyou, I do talred wsneverin, watr 2 you rhe:s'sacant lele sony, you mas(y not
# Ank ve cume tike
# ----
# iter 10000, loss: 52.933033
# ----
#  ing tle5I we kwaun? I w]ul sast
# I mementoustand soog, on'm it am horeronwenvild mere
# You wing ston erbeg frever maediI wiar, heame, nowr, you mind
# I wnovar bast
# [Cloreed buiv frrel
# Ang youu thoul, Ohe
# ----
# iter 10100, loss: 52.611879
# ----
#  was cleren, it wive doul cave cet
# Ta aleme
# Re, I sas be (Julg the n---------------------------------
# [Bun nos docn in'n fore yo you anin')
#
# [Caus Teas the forl sombemy ak the in the ke at tave den (Le
# ----
# iter 10200, loss: 52.290811
# ----
#  ong for hhetrid
# And my tkame
# Wind Don't nomykfe locafnoso'' top ghe еou dou muss sot-
# [Pum
# Jud as
# Ook lhote st
# Aok
# Wind gade, won I dousvend, wase you
# Chust it ar poun mous:e maptone you photue me toh
# ----
# iter 10300, loss: 51.797899
# ----
#  n: nowayow omaime
# I'r I jing of wown-dous shorus steast in the w&vere, be, you oit gon I jused aydoeld
#
# [Chore?
#
# [Vtricg
# Now't ats)
# Thande, hart word an you min
# [Brbe, druine
# Wrow's poustouc think)
# Lo
# ----
# iter 10400, loss: 51.743740
# ----
#   in yun' seling nelyou welseln, lit
# Yousame all neanging
#
# [Verr
# I yfarness, yek I wod fiol dhecredned, gigh
# Wive sas yooup sas poind alce yor seven kn
# I naclest dead
# '1-ou wame tevarded wing (Evetre y
# ----
# iter 10500, loss: 51.980141
# ----
#  eed sne Brethe tod wevylren peling eake lorme
# pann[Pug o]
# Art shouskes than the fany jumd hays, ge'lk delsttopersod ([Vep nid tairute?
# Oh--That momyds
# Lorean ins as I mars getle le mamy gadlowest
# She
# ----
# iter 10600, loss: 52.102248
# ----
#  oh
# Doned yoou thawe
# [Bor ag?
# I]
# Ffid) all wabe fevatn, whe loveres
# (And's ay, you'rs
# Buss a arse
# Youbest aul ing hat aek bides
# Or)
# J1[Che In os lore:
# Bust you geat yo be you I ald is me lave my cow ca
# ----
# iter 10700, loss: 52.388534
# ----
#  mb Irm, peminR, an'l kind mambor)
# nid ind's op staylyrof 3: bure
# Bath, bomenay
#
# Bon (Fousnacke And rovid tan's bon tothem Tacrucsarto ofrucr 3;[1e 1nlon, of wbese me uth llik frroend dneare, bortimy d
# ----
# iter 10800, loss: 52.501586
# ----
#  s.aapnen, at'e avern tlout weanem or dast a dass th low, Sne is yuu I pustsa tulk n]
# (Brerfe my weing)
# And e withars on (T-anatet ro you
# GVet
# Ale corse nowesiskls'me you men)
# I ving
# I wann just a er e
# ----
# iter 10900, loss: 52.358937
# ----
#   thoonand oo
# yth))
# I, ssrorut]
# Aod tolik lutige
#
# Hom the gat it tAasrint, sicrime
# Aed I ith my or ind you
# how nicver spacd ane
# I ho mcid lek on (The mat weed wubyDoh, ber)
# Ank I't mey an, oh
# You bome
# ----
# iter 11000, loss: 52.157270
# ----
#  toI cboll so cowh wan that)
#
# [Vit wexsam It o cun it cfes pome
# I't ot I doyl giscres
# Phe rus
# Thas fery ming f]
# Sa k:Bud witht sin uf Tine'm now
# I wabep wits you's dick in the site haim
# Yow alomeen Jug
# ----
# iter 11100, loss: 52.123887
# ----
#  over ans loke waylor apses wow no kast ind bity rhet ina
# Lir bles wet ha ring aus: pelle ap
# Rben tove ges one ous mind ne yousmdare
# All I wt hougr you nod, bind'l so Shindy an there youh, ither
# Soed y
# ----
# iter 11200, loss: 52.040864
# ----
#   kerme ind durtith tobers]
# I-'Chore myous aoSlon seet on wking I c fust I fwaghfir a llow arrus]
# Exathe bept, dound ller thon sould youlls me bngann
# So I end thins, me I dnoveg, gobamy in (And the me)
# ----
# iter 11300, loss: 51.792505
# ----
#  furt ar rethe neyU ber 2ig
# Hean
# [Archrobee you want mTay, nama nigstaminn on wave Swapldemy dle ofrere]
# And ol an waf
# I, staylones: 1]
# Chow nay tonad, on weyowin's kompirse?
# That ow far on youl f ywor
# ----
# iter 11400, loss: 51.583315
# ----
#  opke tidaig, 1'kou's taust?
# I'mes
# Lato thit bon tha oin'se goonh
# Sot'e you wing angamo youhis thamey yom wand af then bever, an my gigte be-bi[De on, hoou Bust you bare, en'l you'cre you wevI (Oh, que
# ----
# iter 11500, loss: 51.569996
# ----
#  s blot the goth tound
# We ary rher]
# Boh, ale stikd)
# I'Chan'w and
# I'ver Tand Ha same ffee, dike Lip und s yrur
# Oh)
# Seprdebre
# I fas I I mallen fik atd aine you toe ouk ald thas and mee sak: wese Rlos ris
# ----
# iter 11600, loss: 51.832904
# ----
#  d itonchoom 1]
# So kohe nat it ylight owar you ricn my yow ris julst case an, "
# [Chare-do kine win than the rtacllre med it bloned th twavere]
# Ere fwit satl ton'me hhith m
# You''rs-oven in ylurf
# You wo
# ----
# iter 11700, loss: 51.936275
# ----
#  'le wend, ind in tin never scat Ather rind rrifre amind my sare, rith gote aar toossand
# Lead gawls werern)
# Ser)
# I'r me
# Gead
# We licy irw
# Ang thorilveld neverp try mased $Cauts tharo)
# [Ver yourgest
#
# [C$
# ----
# iter 11800, loss: 51.806953
# ----
#
# Axkew
# Angid ereys, ur on6Juld taye lyo TatliAns yasw bhes you pomin't natas liYed not The some
# Ousl you're in monis 't leke ting sus myGak Boprigme thas terlig thowt, be
# Butt
# )
# Hor gosl hay rowingan
# ----
# iter 11900, loss: 52.095934
# ----
#   you'sred, She you gpete futht"dne you purane
#
# [Verng the med it troned so seatt youn Cpas to afe wat cide
# The ians fould 2he pay, sove Jued yor righes rasirs ones Side
# I
# Gofe end ildetd end the yo he
# ----
# iter 12000, loss: 52.026722
# ----
#   fing
# Anl o ketarind, digid
# Ticape chimeredt
# I w tomywh yerug itid thamftrecn, were likperet wo lulse paman
# I seve ftaft the I loug thes, that bapred bean facketh herse on crooh
# Thans eélige Cito thoi
# ----
# iter 12100, loss: 51.999657
# ----
#   the bise cwast baslinet I theres, my is hhove my the an forid't wrebebmebslert you'se ming, windy Youhth, thithsest it itn been thory ant sa I sten in boress ehe wive belssind dowit do ceass gide
# I Y
# ----
# iter 12200, loss: 51.751204
# ----
#  ongdste acktertand an ow the you're at bike there?
# But wing, or I cass andre met me
#
# [Bre to therint, oo, eveg is wals hon non an[Chour)
# Youh, sop allow be
# Bike
# Ap?
# Theris tooh me?
# Nack it say ithof r
# ----
# iter 12300, loss: 51.525319
# ----
#   me)
# I, it'm als it wit came I my bith you cound mighs
# I womn've maldt that Thoriy
# Like I sfingine mast That?ime
# 'Caulg, hars beecren what you haing
# uCwablink you werat calls if"
# But minow ing I'l so
# ----
# iter 12400, loss: 51.358624
# ----
#  Hyor ​ik moods the you kerle got ithes the I'd cant
# Taysow?)
# I dnon'd cer aud
# It myllimame now, I make'r itn watle he
# Noube's poow the dean you Pasce int wit my, at thevetl, wi1Enowe
# The co the cowt t
# ----
# iter 12500, loss: 50.983016
# ----
#   it shoon how thingine
# In thе thon's 'the liry beet
# -6o-Echeantos
# Srupstiog the rlir, I thow bund you loos So ked aist fok lios whes you rekre hutt ehes all in way tand dast youh-Vacsed
# Me I I dior sh
# ----
# iter 12600, loss: 51.081549
# ----
#  e'st you apbees, Tay!mar, dyout sunte way creren "Baghes s]ussellid'kod me
# Ang I wo sant (
# [Crin't wand
# I'nol ghony
# Juse lyour whenk fond orl a
# Tastironivs loo icht fue
# I jus andes
# Towipsen frowe
# And
# ----
# iter 12700, loss: 51.240137
# ----
#
# Eckeas wna aal, the seath (
# [Srede
# Dow (Snomiblot'r what wath stroond wiRs lik aed)
# Dutces
# [Chorus]
# Low allyr ap, on ane, yow qumes
# sat-o
# I noo'
#
# Soulse got the hoast'ss hjon)
#
# [Chor stalpe you righ
#
# ----
# iter 12800, loss: 51.134618
# ----
#   ift sid, horon've freal-dartin watreet
# I' ause of trow lo he bit, dand, It oven the likeGets
# Ohe foudent, yourn syours and jung berenst
# Yeame
# Anca jute fives)
# I (now w, aid it's Ohesfemseft, it asife
# ----
# iter 12900, loss: 51.361162
# ----
#  ne it't Cis beren one yom "
# [Chare beGe stce-tead tow tonl us go
# Oud crie (I donghnn'tr cnow, cocoon than't tuce bivere wimig, you it yau hevered cine relr)
# Te ere (me
# Seyaker han you at in touk]
# Ast
#
# ----
# iter 13000, loss: 51.494124
# ----
#  t'd all my, snow dircaifud (I aun ecded by mady
# Loruts tply $15Yo gomd thing, you aun wouen le youreysers ​trind you loongs fay!)
# (How, onat bighe
# I dlawery, it beidd walle riit, ay
# Hooke
# I s, your fo
# ----
# iter 13100, loss: 51.430286
# ----
#   towen Tiot dooll say $kerirt sass ohowht seon Byou govy, by)
#
# [Cere"
# Suust yous cow, 1pri
#
# [Preche
# Heakithe satam, sanet
#
# Noollon Sor But ith o
# Anpmind teesses, forsas]
# Jus: be becllre't carunt's dor
# ----
# iter 13200, loss: 51.469290
# ----
#  where
# (Base hutle cat I we also?
# Pken "uly of sightrverbed Vere on copr ik whe kno llaplrimincon wanc u beghat os me faks watr dit som
# Bnce]
# Leril's pur heyous fell and like Juth, Sow yer It for omen
# ----
# iter 13300, loss: 51.446953
# ----
#  ule tong oor gowh in tor to t'y stin' wars letly mumbuyse torl all cous the borusever han the It meall fyou yo$r In Croredse wame it's my like
# And, I'l wapreeve therith'n kees gowing
# I'vic my aus Stii
# ----
# iter 13400, loss: 51.362132
# ----
#   fore my was it you perking in' merdig sta banep pearxe pfo lbil wouth as show Taudiy a wapel
#
# I'
# Lomus]
# Youh whe in the I for is be, I ke maug you midn feret carse
# Yeup it I where t you) s
# Like wit's
# ----
# iter 13500, loss: 51.338823
# ----
#  ome haik
# [Caf my on the thiverame 1]
# Pit you, I liv anl to cass so wauving sothennt car yourde anct y‘oust maan
# [Crorn)
# herone ys
# Pute sovere ro moout nome gant you than thay hot's keck ive wnoongot't
# ----
# iter 13600, loss: 51.282803
# ----
#  e fore don a ing
# Tick
# Rayt
# [Vase you gof or the to mincs al to gong care
# You Juthin wodrafon 't tloked on miklr frore
# "
# [Pres
# ]
# Wa eake)
# Nor me kend the nay, Tain the live
# Ip lankin the:)
# You'r you'd
# ----
# iter 13700, loss: 51.290141
# ----
#  s aw, beLbelst in ullse kove dilm miden
# Ave Sot
# Shit ftrabestsigkanen ha I's trecw betlerd you kiow trighend dnt)
# Sren, fos ​hus qurte't it pily ase'Ca bayt
# I mad in r in the pikad (Lyoh, hos's soed
# ----
# iter 13800, loss: 51.373424
# ----
#  st'se on ghe (Chorus]
# Migrast ma gitat Vead)
#
# [Sanen
# 'Ve foolllick maatus]
# I doredshd, go wath the rin'me thow pve my che spepred ae boodould no tigeth minte toume?
# [Ohhe
# 'Cerad Elin'm wintod whace
# I
# ----
# iter 13900, loss: 51.176818
# ----
#  e ow at coonT towagtet you wact wich
#
# [Chorus]
# I)
# Howh
#
# [Ver Tives me biln[363-Ckoroohe
# Navem for the Ir tha woong, cowame, afdy poverust reyous prorigh the me you "ne deruen
#
# [Erce]
#
# [Oun hoon-uftne
# ----
# iter 14000, loss: 51.264687
# ----
#  y the hegetith you We kyoreave deas saon they hes oh)
# Leroes-ou
# I clis thin ave te ule
# Ak &um natray
# Weeson' kin a hon the peaven was thamen ame, storon't awr
# I'm how sXay, tarse a cone, yermirsse cha
# ----
# iter 14100, loss: 51.321282
# ----
#  ireg
# Whe I would giday, dina miochet win wime ffon']
# I goem andin' me aans
# Em you'se howers at on theest you lecalin'ly gfam, datroeget as lackem Dezrin-
# [Ph, I mer ain'yr cloubmow)
# Your he ronet
# I te
# ----
# iter 14200, loss: 51.425547
# ----
#  ing ware, wet clinceste, (Thout if os be wemure dick tall thers
# Live
# Yipre
# Ler, I's dous tked it witl gofts meyor, sith then wer
# Andou then there, rlnst you, dueve bitlmine
# I werne borny rerbelon me p
# ----
# iter 14300, loss: 51.081078
# ----
#  at git same it ucace, berens?
#
# Soh
# (Nok weth ghenl cose at pomewinc ther there rled witr thes tod I'l dall cas ther nimy gikes, ye;r t
# Saf shingn atly, thelr's bey!)
# Bulst'me live
# I'k cothe your it yo
# ----
# iter 14400, loss: 50.998160
# ----
#  pedane
# Bland wad  walr alloohkind miftins star
# Malnifl'ver
# I
# Wfind youhetre]
# I daine Is ake
# I wayl weprelow I waf 3]
# Lall winbas, thap, nos 1]
# 5Hent waik ist bels yous loow, By, your ig hay meed, wher
# ----
# iter 14500, loss: 50.755535
# ----
#  -I
#
# Don't dirt andild 'we ond ow ay
# In ylabBus]
# Reane, Is me to mey) cikied that you rite abe, me anme you'm then Budd mDight, ni[Verzinge the rerbas s]
# And So nevit belse git und is maun
# You futh
# And
# ----
# iter 14600, loss: 50.759920
# ----
#  lorugne)
# You low)
# He ray, as tidrting nou my fare
# So dees ne my wabe
# Sasen, butate fler
# Pals the me anted sstayloous' ca ticcaing thich
# Yherin't be lote I lif'trun, wave on therus]
# Wfith dens, becren
#
# ----
# iter 14700, loss: 50.593252
# ----
#   the wind it never It ink cave I na urfenk
# Wingsen[I're Tas thins, biferne ankn sticatiTh
# Forus]
# I hisg o muk]
# I feevet you mist noche
# Pedon was teme It troore
# I wand wistring
# Fonn, sweeve wicd 'laren
# ----
# iter 14800, loss: 50.337890
# ----
#  ed deng tiln fom mirt-ough sos-
# Lo)
# She you redere]
# Brenm hat I's my
# Rous't y
# Swine
# [Srun the stofep lot waylit waveroing it tik: don t've lall, ne, you
# Thin bee fous nowlen awis che op wonrs]
# -Cuth y
# ----
# iter 14900, loss: 50.034501
# ----
#  Mind
# Oh if the scote I tike
# But the wan the ras snevesre htore my statd, bleed the pous yourd shoust you' me to nikny! 've ane I hore oncan thoyle melne mist wo don?
# I gont't a wast nomk both, jutt it
# ----
# iter 15000, loss: 49.544339
# ----
#  bt ake mast soo rheed in]
# [Ohe ing breiggint youé it
# diaght
# Mar ?h
# For in fas waylon minden you Yruerte
# Youcas therp I mase mow"y, jurtitl ot wist meney(She cabened, in
# "Myrigh
# Ne me wit like[Bret mic
# ----
# iter 15100, loss: 49.654042
# ----
#  rm giet thoary, you row, geretw stasts on the yourmir devean light seasp you's ch't pall waly so ly poom bedionl
# Ang sarm fat go le me
# Some
# Ang yo
# [Cho your loy
#
# [Chorull wall
# I me
# Is oust?
# Youhst aus
# ----
# iter 15200, loss: 49.916641
# ----
#  t lamy
# Snot inod rtatlall nevem geLyh
# AChuy the serea ind could
# Surs monet the geen
# Bust I could l(Sme lit love
# Oh-lithe 2]
# Embad
# It'r ming riick llas $‘rucd ipe onasingast dokn an the llowl me whass,
# ----
# iter 15300, loss: 50.024013
# ----
#   geel mave you at in' me po haxe
# [O dast your you anewgaytusn Bese (Aol ing, dulse onttil
#
# [Pre
# I's as the woust it me
# Stimenst it'min’
# Ing toongight
# I doo wall all wror
# Chars)
# Thanin't an tlatl troro
# ----
# iter 15400, loss: 50.321755
# ----
#   roI dod acing ane dney, shal
# Ant: I levere fane
# 'Chery be
# Caonht Witin’s sitls
# I
#
# Carereen hoo, (Ou, Caord nem, neves I deden to it?, les ast west if your out)
# Bule wwall and It me lleve gon' loke ma
# ----
# iter 15500, loss: 50.397841
# ----
#  rs wawhin'd Dwet Ver bed bay rn-you jubm (You Ewdpby sha torufn, your beon, it)
# Bust we bast tay)
# And owata gighe me ftid ay)sto ass gonnet
# Radn't heckid on an's]
# Chirbemoble, ghebut I tod, an tha got
# ----
# iter 15600, loss: 50.307401
# ----
#  ty as thaog, ypuem the goon, tanen sey, hik't a mumyr oh-ou Taon't woant my Stiget oul mistate Cause at turin't bed demy whink the: do, ou hingy bid nams you dow enou
# Anl wind Tas the to to yfurep the
# ----
# iter 15700, loss: 50.059427
# ----
#  r stasas wor shoulí it (Caylou, I cake'g ylor, It meay mi
# [Prre
#  ooh
# An lea all
#
# [Pree 'lle waylor mer dieke (Oh-of jh trlevers
# Buf in
# Ave elnan you wick endy cker
# -o
# I know, "I whind you'nn't be tit
# ----
# iter 15800, loss: 49.988609
# ----
#  omight, lous
# You me ene all kees thiplbare sind a me wher cow9]
# Wighe"
# gncawh thacins I
# 'Chad love lel gome don' lous'me the Tain
#
# [ke gowm toang tose gotigh, stan) oue
# W])
# You Ros a solld, Tlorusnedr
# ----
# iter 15900, loss: 49.946009
# ----
#  Eme ais, you k my crama
# ----------------Chorus]
# Tay tare:
# My cretind sulghe
# Wha ghat (Got and of bem the no Live
# [Prw
# Sow the mu
# And
# Iche
# LoveGest whack an trood s]yous you, a gos whing
# Tick, laym bud
# ----
# iter 16000, loss: 49.722347
# ----
#  yrupe e]
# Aunt I kow Aicen 'ner dous, Ta oh
#
# [Bom thaas one never bagh To in
# Liue'ver dray plead
# I'm inly cate ep you were]
# Ynard
# You wnexlore
# ]
# The pulind
# I o beare
# -C-ohin'n wham thin-nezsed on thlar
# ----
# iter 16100, loss: 49.656687
# ----
#  reyrist
# You me
#
# [Pve be go'lo nave pit me til
#
# You gfay by in' so hear
# Sow?
# Begit
# Lorkid tikt my,r, in't we loce you fon be-Chil maplind arn
# You hack thes sace"
# I genne in
# Myos
# I me for cwilly, wowht
# ----
# iter 16200, loss: 49.673415
# ----
#  s: my, sfreze]
# Oo?
# Ank I gong it rid's that amd
#
# [Chece anese?
# I ​pouse nome
# T-omuk]
#
# [Bre" you dofe pristmere
# Alin taan-s--oh-ehet
# Ther sedhe bers silg you'limese lous an's of thing, stuts averidbss
# ----
# iter 16300, loss: 49.935185
# ----
#   git yur ore hen cus alllinn
# It all bucbe sas-ing erabeer) ding
# Bris lofy ce lother med oEmb
# I go wetss bore'me s: Tal tho Ftike
# Ther dowp
# Ath belblered thas merabyegring Cifmy thit
# Ler)
# Angs-sing I d
# ----
# iter 16400, loss: 50.074342
# ----
#  's laght wese I' lood int cered
# Buts
# I tor was leved gocet youn thong
# You're ton't cund
# Mate you amdre
# Taylfered 2]
# Your in) "gigs che faid in af at rers)
# Lorme wale Tain
# And noke rim
#
# An's and
# I stre
# ----
# iter 16500, loss: 50.183874
# ----
#  if? haylu tome"
# Axd-op cut my liked tis wink Sse?
# Ash
# I, all sackamestis
# Me pylse cagh a dastse plofingd the onet I ankil the soug o me tome
# Beren lo git toliwn beel tatst bike uose gas rears er mame
#
# ----
# iter 16600, loss: 50.328426
# ----
#  e pase the Lichts
# Lele poln't wann stiep sos Gongt want to righ ase likend tave bive ackighe weshd gamy bomm"
# I've tonginse thein
#
# [Chorurs]
# Ching of the an weed bif to Dres, my go youn we the kall-Ca
# ----
# iter 16700, loss: 50.298556
# ----
#  herse gow
# Wher kinges]
# (YRered ther rath you 3cod it lotser the are men
# Wher pighet] "You fusd phe, ap by sfit afy uleinezapase mber
#
# [Pre, plaked ive ip is my your the tint gfay
# We potdese ther
# Hes i
# ----
# iter 16800, loss: 50.189996
# ----
#  ------oh-onowsed To love in ine ure my of card los the to so Tasched $Ne touth
# "We gigh, we bo thut fyon a
# Liongise'k beesooh, whaclo, wall oo'ts I's cating rtore your soved oun the bet loon, youl eri
# ----
# iter 16900, loss: 49.952681
# ----
#  t I you I than me ther hall the covut]
# I''t fow touse (he I n'glew I'rin't thees thos
# Tallaw sePmely titceed I roong you
# Soo to horea pive stow mind om
# bealpese
# And 2Or Stitesermed whithe it me Ligous
# ----
# iter 17000, loss: 49.690058
# ----
#  l ace it's wedith a walshoul I dick ftisay you deang you an itver dylor fand llike
#
# [Car therle'Ft wfals it bler thing wel atdacrimp it't in me birdy'ver wart as aus, you hain'se ni't haale wheth
# Nide
# ----
# iter 17100, loss: 49.473706
# ----
#  s, weves it Tivebryen mentronny:n'm aus you unoringad your itk bey at
# BongwPre"
# Kaese on that
# Anked dotht it ringive cow pa mes
# Setarte live eecay it my ream afrucill andy wloollow nawHerse't aun tins
# ----
# iter 17200, loss: 49.432989
# ----
#  ln't a creefprentesent
# Dleyllover
# Lex 2]
# Bust pire
# I
#
# [Ver hamy or you, ip an?
# Whond tome, waus you all atre You wand fingin otr DoveGest
# Delsned yeus gome fooke here----------------------------------
# ----
# iter 17300, loss: 49.485638
# ----
#  or ant leveet on't (Is andse? 275[Ver
# Sorafsy, 2]
# Cher als avide foth sfenatlo mink nightes a?
# It Pnotind winf
# I ho golnin' you show &2]
# Yo he htat thidp, lowinke my
# Lolle it cobingh tidmy al
# Can wilc
# ----
# iter 17400, loss: 49.587666
# ----
#   the herl
# Life fume it know sand wast's stow
#
# [Caf it withe if whes a both
# You nime af le westift it on so
# Tan? it't custard, carun, Tothin wermesed anm fir
# You'bos)
# Fon'ding ot now it't yo-h-ooh
# I he
# ----
# iter 17500, loss: 49.598942
# ----
#  , Bong your wande
#
# [Chow, waid of $Caus, you hore
# TAplive't funes
# Whised ttat my al)
# Ast I mn'the on mo it your theve whamsit?
# Ih,, wond staobon
# He the atwyer ic selkhit dime
# I nay diokedn, yeallllick
# ----
# iter 17600, loss: 49.700645
# ----
#  liom (Cag cnest
# It's mopshe 1n tevevan onins, whas "Alloul thear, itid wayl lowim tong it wesps"domin'me, so cumbestand I do tiep 1]
# And houg bed llant fere It'ac? Chorus]
# I co caddend fof jutt llano
# ----
# iter 17700, loss: 49.873284
# ----
#   the bever reyd, phiglyow
#
# [16Ewd it wane ked it like tite feads, titaye ew
# I can]
# It bued whe mad Dhatn't Tidnonl oase ont beven whe doy
# Lifrest it Lals
# Fer you've bakn'lved it'ver fome
# Chun thon, lo
# ----
# iter 17800, loss: 49.830631
# ----
#  act bed th
# [Prеim
# Ell tick
#
# [Cho lo hitd a poncadne
# Akisetn I we fime?b
# It go ne'll of ghe it you boongrad
#
# [Verin mbeGet wrlort 2]
# Soobve your Pontbiel reass stead Has the ce titals, ousald tas thas
# ----
# iter 17900, loss: 49.871120
# ----
#   at apeaming
# I I wall sick ended
# Ald, pereas: you righlolling tascowdry, wethtle toul, I's puiked
# You Juss
# [Ceorit'l lo cane
# Cacle sow In on'mun]
# Swets go ee (Alsoy in the Larsen's ait
# Thofom, I've be
# ----
# iter 18000, loss: 49.833617
# ----
#  rd flekn mey
# Is cwat
# ]
# Witce Taylo nay ois a fhilw lo ?I hber3Ding gike me
# Thare ant
# Deverem it' be'te fure weas
# Thats a mutf lley erouses 2]
# You a beem Taadut ’o levat the ficke]
# (I, got)
# Somine yaus
# ----
# iter 18100, loss: 49.867355
# ----
#   lace
# (You thay ore think I't wyouse withe hecke live say tove Is are govight the cresssig five
# Ast
# Noken
# ".urt's anind lap oen haing,
# Noo Naike in were a blous ave is mighen thit'se w'no tow arm tha
# ----
# iter 18200, loss: 49.787598
# ----
#  fus]
# Thald hiblu
# Sas you furs the cacanot akidl I hay gomyin's are
# I' is Caac
# Thon ald I me riftis your It'vis a sisting doulld $165he hevend, ars, Doth
# [Prre
# Oo go ror
# I bodes, bo me
# That werenn the
# ----
# iter 18300, loss: 49.792491
# ----
#   lofe nove glorse
#
# Mve you'rees now we ine it the sig ams
# Mne shon't yuun
# Swe lane all mouss it for nid witht wrent like reat juXd bon't it wank I ove thet as nil Vevefnedgny
# I alss evirs She torp fhe
# ----
# iter 18400, loss: 49.830743
# ----
#  ne
# But drofgits
# Fel heconone tos've]
# (Bre (My biedatd re dnome
# Th) nive like've whorssan a lave long
# And
# Evan)
# S]
# Hous my beed minf sod's the same
# The knowht'r Is a mid
# [PonW
# AndoMe-Chaends mbice
# Soy
# ----
# iter 18500, loss: 49.879368
# ----
#  Damy I wan $16555You mes
# Howin' beAcr, sos)
# Sry of no
# 's ubme
# Oh
# 'Chouminn't wnow, thing deed sobut it owhth
# And me yo han't may tot nad the gion' tot?
# In you'r
# Aod
# Ey srighF slir pruth I nen hy mees,
# ----
# iter 18600, loss: 49.635042
# ----
#   2]
#
# [Pre soul a fan't jut youghy ken hoom at lous the waagh fif knoh
# O2, a swith gok malyoun is linte gayla prhink fivink sest've givesen'tin's taust dads  fice for tike art fright dave tow an tin' a
# ----
# iter 18700, loss: 49.832773
# ----
#  d ing pappesight yeause mere
# You dous a angony a whime
# "Stica sapl tame
# Dooll clidlbes, brirtimn't a kausong hot un (Latle fil the a mame ha waylured perennow the lot pur you'ls ou'm an thery
# Dot and
# ----
# iter 18800, loss: 49.926741
# ----
#  m sidsed it god
# I hickiob
#
# Wow you, warsight ito beet yole beWh) if whe wer shucn exer bet, ing I]
# Shis, lin' face tow turre stiw frer 3n toe a camess wand whad ben 1]
# C[Chught've bake wabbeed me me l
# ----
# iter 18900, loss: 49.959125
# ----
#   ler in
# (Lyrre fryouns ave ae "I thethe
# You mirs there, I whasaylbe's oor), was it wuct ftice hool it leas ry my ghet 1Caus an tree it your teedt
# Izy sastep fore licky me chere
# Khathe ah, a corich
# Dop
# ----
# iter 19000, loss: 49.601003
# ----
#  a wair
# ----------, rure)
#
# [Vere thath, the rele
#
# [Cherutse you kne stick wowd for therle thet sin't )I boous abe in foul
# You rapse for ther gy yrurre er)
# I crake a proucs ive you wethe rete where Ho L
# ----
# iter 19100, loss: 49.639616
# ----
#  wlim the reylon wouste I, thorus I wan' coete my medt hisCaumtin, you my srool, is when the frigftioght win's chas so llif thollat onl he's on'sa dinewn bihel silg It Uhe ald wnewy
# An I kecate'l all n
# ----
# iter 19200, loss: 49.403498
# ----
#  vere (I.'m hee snow end a rustindm I wI d]
#
# [Ver eed a drealb pound, youlr you you heed no nchimk ty said thow the ring coе serwef there bid
# I's 3utre your it this hever tho cruen've ah, belk tace in
# ----
# iter 19300, loss: 49.402505
# ----
#  g Dive
# Ta fof ning
# So ryeve, tray dnond sever thowerep
# Romy rave slabe"
# Uhing alit
#
# [Varn, boumd gitling say puen as wand waye niss andade
# Live wars, you, int Art eresery the ryme, my thow lite han th
# ----
# iter 19400, loss: 49.227812
# ----
#  nk I'l halndout In cufty
# And it musted, now
# My scaipl-"Eveed, gon theeve yarn sexreicem inin't dor fere ssoneg stassed mist lit your
# Wa toy lele noNinl you sand lillo lovess wery ghelsed, weaif, cowou
# ----
# iter 19500, loss: 48.987811
# ----
#   dheans you woong 2]
# The coonon's unde severed ware of tre the fhet waid onet cor in me to, Dourde houll on thiy
#
# [Ver sand was our I'g thing be thieg ere I'-a rele me my ghet coon wand thing you chee
# ----
# iter 19600, loss: 48.609809
# ----
#   for moone thignt the wende mime
# Wound I go you's
# Sehе is low, I he tliut do
# Dek mid the as erune to mody ne)?)
# I've shor?
# You read thall, alloone?
# You vetat wheke min
#
# [Vest mid the plaoke to ackell
# ----
# iter 19700, loss: 48.162930
# ----
#   woud I wend judeen berpest s
# [Bering whormed it do
# Dopred
# It name knom friemd whis you canded
# 'Cout dnewad hist in ase (Veread touldemee]htas so knes
# Whergest rwape apeud sorse your you kever I done
# ----
# iter 19800, loss: 48.437495
# ----
#  ghay no
# Tyo tas for rlady
# A cants
# Is I've geverd is loming, lele astinc, wiin
# I aw therl3
# Youl my my, hay us allus comes
#
# [Brls tlarcrastorels, saske?)
# LiveGe wornem
# Phetas weverbed myrulclit
#
# [Chould
# ----
# iter 19900, loss: 48.699312
# ----
#  n-Cior ghe laylel sime
# But ice
# Wet teare, I sall cant it all-o
# "-----------------------------------------------------------------------------------
# Seathsned
# (Jres pabe
# Gots and
# U---------------------
# ----
# iter 20000, loss: 48.912683
# ----
#  gh to dea("I't dryrease for scassthe you gumbylbe, yun averiin'vere
# And enat or becen to med I howignest
# In the sai'
# Best is af
# Loek my the do
# I d mive fice ond hand o])
# ]ran yilk
# [Oull on bide to hom
# ----
# iter 20100, loss: 49.227549
# ----
#  here gien ee a rape weall tarlit)
# Sryip tomy
# Leve:
# An was the rin' be I dight it wayly whay (Oo
# A sok'try got sevorust
# I' toush sight be[rreamy pith if it maoke'l rume
# Bere
# Wiok
# And all ne ind Tangid
# ----
# iter 20200, loss: 49.223602
# ----
#  you sanc, the fery ues oh-ohh)
# So in fonld srast my, I round thing ant like a yake lave shat is aut's or Srigh?
# Ew, it aks ause im Da frepyen?Bus]
# Sot I withe ay on fafe jed whas (You mavirs
# [Ver that
# ----
# iter 20300, loss: 49.041808
# ----
#  at bidewt
# I wind yleas it tareh
# Dow, hit'ls herberoust som gomy
# 'Ca lleok dom I'm arren ChiAl
# Apt the: And the wamining it ous thist it
# 'Cour yuuprus]
# Bket 1]Ge2]
# [Verlber you mant't to custle levеd t
# ----
# iter 20400, loss: 48.898656
# ----
#  ng tha pive just aylin
# Se trerins whas (You cors, in to pome
# "Gort, cheyr wrod that I bart tOe that't thet it ow"
#
# [Chorut]
# For Chestecwbins the "as ke mecse hidne]
# I ditht jupmed was caus the crungil
# ----
# iter 20500, loss: 48.776522
# ----
#  ----------------------------------------------------------h--------------o-h, Dow ylojbuts llone
# Whot eh)
# Lovereet noke my've hekng in (Lite wong at tow, the som sexiude
# Is mese dane
# I I]
#
# [Vers you t
# ----
# iter 20600, loss: 48.686631
# ----
#   ((You gightean Thet ondase it bagh-nagindboke mall that?
# Bute dastowt
# It've gee, frleud nive corly)
# Your
#
# [Preamen bilgot
# And we yaug I fren muse ked in to nigh tho peamed in ?uist
# I it my I'm not?
# I
# ----
# iter 20700, loss: 48.543968
# ----
#  e fregh" sean me frigly kan's tomering I'cre I: houbepyen Jel, the I me in you fad
# And an to titl the dot't I wanof thaik I dease tha came ((You wath halese (Em)
# I mise:
# I knowh pean you he my r tow,
# ----
# iter 20800, loss: 48.508287
# ----
#  (My, showise farson'me
# (Eplous ylauste, bone
# Souse liek ithe I ywamerf scaylsechne I'm son[Pre))
# You ming I 4Basamb me htcain'enon't (Loris
# Sthame
# (You me)ding tekin may$165onGe
# And), bey, my)
# I jut i
# ----
# iter 20900, loss: 48.512742
# ----
#  sthe
# And bars
# And I"
# [Ancs my lame's whin are nhan't oessis, ther tus the welgs sere
# Yloversen
# Swing and wnoghttyedn
# Your thign't cead, I guth llvarf love, you de-melll)
# Yeare play fovere], to liken t
# ----
# iter 21000, loss: 48.947679
# ----
#  e I Lidoo
# Buts whing
# Thin's and hight one you coulss, oh)
# Dot gallst stechrot lallbismirun onnd mane Wever me
# That tarse 1]
# Lit it lidly cake wen siRt, look aray likig, furgeGet winn
# Is righe nighs we
# ----
# iter 21100, loss: 48.892968
# ----
#   I I ko tike sues itr my rame, your the meshe fuuse be
# You ferle
# Bust lleacs sol lown
#
# [Choh
# Wer fart of eall al the mastaus
# Anden Taget treat af unt als you ble reise
# Reinl
#
# Aftar so ley
#
# [Orused is
# ----
# iter 21200, loss: 49.139710
# ----
#  easheGrised yick your gitkir suth dion' you pory mabedy some
# Swemine aro rag
#
# [Cho levevere
# I wloveverens me
# -Shis or swit thong
# 'Caall, you mulfewn bey leck, the of son'ws the cas
# Ank:
# I crooth "ull
# ----
# iter 21300, loss: 49.232405
# ----
#  youut one to my onte cat
# And wit like houst in't fow cerrop?
# 8Oh-co!-quO tow yo hall
# I'ver ause Tat wake at way wast dan,
# These thinks liecteor
# Lickinp
# Your ake
# Anh
# An thing louses]
# Now
#
# [Ven't rilg)
#
# ----
# iter 21400, loss: 49.270590
# ----
#  h
# I 'tked me
# I got'll
# You me or ghtall mos mow in withif moanht stoverre, you hore, my thoru Uo]
# Beredind oohe o]
# Swe
# Taylous mins thes
# An the wein
# And I ral cabes atd a porlbeembed teabrome
# Pre yo he
# ----
# iter 21500, loss: 49.100388
# ----
#   dove heng mabeal1 2]
# Yhar
# Heyongse you wall ave bro0y'rs
# 'be weol
# I hhe: Taikoonet the kOoin must hat it thiss
# The it ande bony me
# Aon
# I'm llind gigeal
# Like it you reaks mem
# I hous my knot
# Sand you k
# ----
# iter 21600, loss: 48.930578
# ----
#  he but das man
# Thand your it houd in faiding there rull
#
# [Choruch
# Mule me sad that gotthing than I's  thend Is you hebesed the ylicitine
# I sabbus in cay thicsele
# Oo dool me in And it'led the nag couli
# ----
# iter 21700, loss: 48.627120
# ----
#   iwn, you whan oumonowing tcat at af torer int't your ak whor ofrers
# Mmerron
#
# [Chor fewanol wealithet
# I musеny, whing it at the: an an'trd Is suhe 1]
# I, I want hylir epas-oh
# bu unless in's ime cay se'
# ----
# iter 21800, loss: 48.137945
# ----
#  o llould werding Tave fick it not do uborine
# The boo
# Dhat I mad my tod west, gown"th the I sfers ow ming Cherarone aldelro3? Chon the sso mikedd or Is wat ayloo cheedind dodn't itid
# Heake my gow, you
# ----
# iter 21900, loss: 48.458083
# ----
#  ust my Tit? her go
# 'tlarsed
# In tost, I'ms do the nin't ghet yous)
# Dad is whot all bougryrod croupp, sare you, wand hallse or pheake ted ove whatese mugdin' like stighin my
# Oo mondegnas taken wist jhir
# ----
# iter 22000, loss: 48.518720
# ----
#  o
# I bad ine yourl you
# The 1er fine
# De wan you weyrey"
# [Brabh the be sool, tnow my algittf if Lyar naby you Rache gos:
# We‘lingNcay eed co bon whet belitry)
# Lalk Tast
# And bove so wewre fith mire-for
# Son
# ----
# iter 22100, loss: 48.656614
# ----
#  elss leve looh, hond'verine ith cracly: ex the yover my)
# Thals-out ondinggrusine
# [Chorus]
# Likn yo hate mirifebooh he eon-you an
# Dow unt's stap levetse cord
# But sing ees, sswas yous crit's my fut? tead
# ----
# iter 22200, loss: 48.653641
# ----
#  ithn the wnow
#
# [Vas dich thear]
# Wive (E
# Whty phenr-ou
# Sfever the cas p thetre
#
# [Cas is it's town wand youur in way the crys, hould we ray
# Fretrise end coverent stamseid the 1]
# Nou mery hosd never stie
# ----
# iter 22300, loss: 48.726073
# ----
#   wo sag of beaft:
# yos Inded you as aiver, gos tow guft.fe her fir ande I pphast my theme't cor k:
# Foulse nat ney, dowin
# To caclyidd w3All than! you jus "I k'dousselbig?
#
# [Canon]
# I, nome)
# Bir
# Sel mimyo
# ----
# iter 22400, loss: 48.880207
# ----
#  ftrist"tros)-(Uh-wSthen thind, you ring
# Pacs
# Dech
# I)
# Sh alling
# Lik my in you 3e ip of eruste, my hoy Swet you
# You withe oonmes
# Avardofly fike ullseve they thes my ullifus raalse atwats)
# It dow ferist'
# ----
# iter 22500, loss: 48.768536
# ----
#   beaft my jut oo bume an ont fricvach]
# I lle you horp filetred yourr
# Sreyous thind creambrigody you do cat on the dellay the seabed
# You pook thing har, the on drow
# Or las tatr beever you'd or co cose
# ----
# iter 22600, loss: 48.802342
# ----
#  ]
#
# [Versedt)
# If you rid, don wous me bloove likifll
# I wher Ves me me marven ot to serre?
# Lavet to's kand be als we ackend coy weye 2've lon-Chit you
# Tore 2Edling tay beyro
# (Bunt wale pick
# I hakit've d
# ----
# iter 22700, loss: 48.795893
# ----
#  rme Whalbuse I'm lletrerlick to choy
# The an's riglt in then cours
# And a Swambtin a't you lice
# Secaned tow? I do?
# Thantowh, Ead the 11aky raad vere own weve eroomy hark, loh)
# , me lee that wight toust
# ----
# iter 22800, loss: 48.834301
# ----
#  hime you to calg, ne]
# -----------------------
# Sed tall oh
# But I weid you men lek"
# Delben fokin't shieddiss
# You're, Taid
# Sfor my bidoucd it weyruthe ont ald and)
#
# [Sred you whinng
# It making a bage, it
# ----
# iter 22900, loss: 48.735431
# ----
#  h
# Khe loagen miftime
# And drind I do &ulste thet the saru ho sameeh
#
# [Verse you wan't like Tabe
# uet
#
# [Srissteelingr thand, gopuck]
# But bery ik sat aw)
# I doyl for ith rive spore thon sidd one your if ri
# ----
# iter 23000, loss: 48.773729
# ----
#  e t'lif got I you me fos os ould you now a thithe
# Nom shingsat
# The cren a comy stine doth fint eng ol gool tarly--ush neve nave dore
# 'Cause shanes
# Whe gome I'd hryssive es me I've, ouch
# I can
# Ouveth]
#
# ----
# iter 23100, loss: 48.829596
# ----
#  o hatkt feall tnay, in my, coring bo knet I wakr ferbe's Las me me somerlalidse 2]
# -Calling is Sprleve leve
#
# [Ver so fore my goul
# I wefridn't don's]
# I've wher
#
# [Pred
# And but a quepme
# Ank hang that' me
# ----
# iter 23200, loss: 48.779945
# ----
#  ddre
#
# [Pry
# Is oun't lot lel that I I me it rad yoo medron thire)
# Ap in tha seve seyllis me mest bery deet if Joma was my, you "8[Pust ro weylrige if me gete bus you wal'tul wat pisids whad trols bime
#
# ----
# iter 23300, loss: 48.639980
# ----
#  nin’ (As thaig
#
# [Prs
# Don't ppiet anlin' you whon's niss you a sceedses the me mendon's like go It in my
#
# [Vering the fust
# Dad ais warly, you mare fors allire you warmed breSce dot
# Gom it'in's liek din
# ----
# iter 23400, loss: 48.775719
# ----
#  -the wo]
# Serint Lyorr bet Tove-o tiss tond t'te conobutse mably you llale
# Butt malightire
# In hain, 've forere tumenepinn
# Suld, in thes frirused bil) torRed a dow in mo taking for wain' (I he you ce so
# ----
# iter 23500, loss: 48.852314
# ----
#  -------------------------------------------h--------------------------I
# Siny, yucher to
# You qurareny
# ha sute maylonn'se it therre, whoruss Lit to plont Meve are-cas, you wayla hist troneGet (Fomibe ed
# ----
# iter 23600, loss: 48.523835
# ----
#   wand
# Ald swase pare-ca take
# You oma gecy wealk cabe nels
# Lut Taind
# And I wall
# Swan these mare mofet lo kin'll I rey
# 'Can-Taylor, gontrred
# And a waik you gict you acaun to keen
# 'fem reese wyor geave p
# ----
# iter 23700, loss: 48.514894
# ----
#  there the hhal rid wis a me I'ver,'lr theres all all thele wesang, it me ise woul
# Semy, merse you dofif't sheaplemy, me has my lllering lome
#
# [Verre youllrion, I rey, I were Iiwn ale sail as low alda
# ----
# iter 23800, loss: 48.220833
# ----
#  end dame (You, you knay
# Where on swalve the my
# Is theries
#
# [Cher
# I'me, sod ly)
# Ohl yo
# Sfirtlirs
#
# [Bringib ligh
# I)
# You
# I so memind that wa yleip, tamen ackiohsif way thel knew etht yea mestcart of swab
# ----
# iter 23900, loss: 48.263520
# ----
#  s my repussing ine
# See nod, mast
# Aut
# Way?
# You lout Uneare)
# Andin'll the me othes
#
# [Verd wing
# Thas I'm pawl
# And yor
# Sne a lant jninges I I wabe the Tavegry $16Ever you was me dafacin, you nig ay s-Save
# ----
# iter 24000, loss: 48.180894
# ----
#  mwan fecacked niy, aymu mind tringe alky
# Lyricn yyor somatust wack your tits low the in haiin
# Ged, sight]
#
# [Verres in alsain
# But peed so eod
# And, vominglkee)
# I dodn'n ligh
# Eyws
# We, now
# Ang ces my in'
# ----
# iter 24100, loss: 47.990756
# ----
#  s, a pas bire the go'nem you me pomert, upue goding
# Ben love knom sean1e bered, all so levere]
# Or loll, (Futhe ding you my avere
# And staylftonese ofed sipkn we  lowroplitsind of bagine
# 'Chould
# Bud in
# ----
# iter 24200, loss: 47.792616
# ----
#  Kead, wase llist
# Wame
# Chip wevind a rined the me fo
# Tame
# I got?
# Roy, you ko
# Now diOnvese fen're you juckem Lyril a seam(
# I diin'$1] me: hmys
# I was for drigh you my metrery thele, bary rporls, lod ar-w
# ----
# iter 24300, loss: 47.331771
# ----
#  s: I mame
# Wivese hich
#
# [Chorustren ar thes mes barle of, wtut-auls, I mess ot'Cdurmen in Cabe we the darle'le wabed't to? ring
# Kavedid aht for lip stigun
# Cauctyywn Jut you loen've, it out ho dloll
# Wan
# ----
# iter 24400, loss: 47.048032
# ----
#  one of crale
# Shit thing your gvipabuel
# Dowch all reofling lyow sur your, mid
# You'rn'rrus]
# You for pund, I doufboke quightory
# Lyilk on the on't fronted wing
# I for Tast know
#
# [Choromakenn'lle a some lit
# ----
# iter 24500, loss: 47.236340
# ----
#   you Ind
# 've alrcirl
# My I dind ut tha pomes
#
# [Breplen rokese
# WheOres it you you mid my sling pige't sice hhe cast
# Ooh, you eldin' lon't Litm is
# He like in tow thema tide the enteme, I wail?
#
# [Re sivad
# ----
# iter 24600, loss: 47.537451
# ----
#  t ins a wis time
# And with I me on I Stime Dinget to tighthmes
# And prist my, wifftowh you wend"
# Obedln was, ail one donghst me got'berobiss, there
# I cal to If $165You beppet I dnay in fow think
# I's me:
# ----
# iter 24700, loss: 47.778538
# ----
#  n
# Bren ylor the sainn you seak who tass aind (I gome, you, lovin thigk hean
# Bhet you me stits, I dowht of mamb geum ow I becs
# I'rod, neFinl the lpomoasty jpre]
# I waylone Fushist 1]
# The love[Emoon you
# ----
# iter 24800, loss: 47.983768
# ----
#  r all ut long
# With, a oul)
# You pyisty cone
# Fon treast nive it ber
# Wous gowin son'me bo
# End the redouct nive it a lantw it ayerus, yeurd, whapy, malone yneviss)
# [CSurseto hothan touthan tasd here qule
# ----
# iter 24900, loss: 47.982416
# ----
#  ---------------------ou'll gover it of trease prabecoo
# You gaimedn
# You cor knik dowe (And that in'pmere-enk, when my like[Veret you' lous gont
# (Renow (Whend sall or shan's mbuil)
# An the, ex ah, I]
# And
# ----
# iter 25000, loss: 47.732326
